# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
not_hot100 = pd.read_csv("/Users/durimferati/Desktop/IRONHACK/Week_6/Day_1/Afternoon/Spotify_final_dataset.csv")
not_hot100
# Out:
#        Position         Artist Name  \
# 0             1        Post Malone
# 1             2         Juice WRLD
# 2             3       Lil Uzi Vert
# 3             4            J. Cole
# 4             5        Post Malone
# ...         ...                 ...
# 11079     11080     The Band Perry
# 11080     11081  Justin Timberlake
# 11081     11082      Mike WiLL Made
# 11082     11083          The Vamps
# 11083     11084                 JAY
#
#                                         Song Name  Days  Top 10 (xTimes)  \
# 0      Sunflower  SpiderMan: Into the SpiderVerse  1506            302.0
# 1                                    Lucid Dreams  1673            178.0
# 2                                   XO TOUR Llif3  1853            212.0
# 3                                  No Role Modelz  2547              6.0
# 4                                        rockstar  1223            186.0
# ...                                           ...   ...              ...
# ...

# %%
not_hot100 = not_hot100.sample(2500)
not_hot100
# Out:
#        Position       Artist Name                               Song Name  \
# 9493       9494  Imagine Dragons             Thunder / Young Dumb & Broke
# 1499       1500       Juice WRLD                        Reminds Me Of You
# 3123       3124       Disclosure                                  Magnets
# 10995     10996     Foo Fighters                 The Feast and The Famine
# 8487       8488       The Weeknd   Nothing Is Lost (You Give Me Strength)
# ...         ...               ...                                     ...
# 5863       5864  Kacey Musgraves                                good wife
# 8078       8079   Anderson .Paak                                   Trippy
# 4925       4926    Playboi Carti                                Go2DaMoon
# 3722       3723           Future                          LOVE YOU BETTER
# 7613       7614           Future            The Percocet & Stripper Joint
#
#        Days  Top 10 (xTimes)  Peak Position Peak Position (xTimes)  \
# ...

# %%
not_hot100 = not_hot100[['Artist Name', 'Song Name']]
not_hot100
# Out:
#             Artist Name                               Song Name
# 9493   Imagine Dragons             Thunder / Young Dumb & Broke
# 1499        Juice WRLD                        Reminds Me Of You
# 3123        Disclosure                                  Magnets
# 10995     Foo Fighters                 The Feast and The Famine
# 8487        The Weeknd   Nothing Is Lost (You Give Me Strength)
# ...                 ...                                     ...
# 5863   Kacey Musgraves                                good wife
# 8078    Anderson .Paak                                   Trippy
# 4925     Playboi Carti                                Go2DaMoon
# 3722            Future                          LOVE YOU BETTER
# 7613            Future            The Percocet & Stripper Joint
#
# [2500 rows x 2 columns]

# %%
not_hot100.rename(columns={'Artist Name': 'Artist', 'Song Name': 'Title'}, inplace=True)
not_hot100
# Out:
# /var/folders/7c/z0n49jfx363b963q_1747v7c0000gn/T/ipykernel_21266/579651624.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_hot100.rename(columns={'Artist Name': 'Artist', 'Song Name': 'Title'}, inplace=True)
#                  Artist                                   Title
# 9493   Imagine Dragons             Thunder / Young Dumb & Broke
# 1499        Juice WRLD                        Reminds Me Of You
# 3123        Disclosure                                  Magnets
# 10995     Foo Fighters                 The Feast and The Famine
# 8487        The Weeknd   Nothing Is Lost (You Give Me Strength)
# ...                 ...                                     ...
# 5863   Kacey Musgraves                                good wife
# ...

# %%
hot100 = pd.read_csv('/Users/durimferati/Desktop/IRONHACK/Week_6/Day_1/Morning/lab-web-scraping-single-page/hot100.csv')
hot100
# Out:
#                            Artist            Title
# 0                  Olivia Rodrigo          Vampire
# 1                   Morgan Wallen       Last Night
# 2                      Luke Combs         Fast Car
# 3             Rema & Selena Gomez        Calm Down
# 4                     Miley Cyrus          Flowers
# ..                            ...              ...
# 95                  Morgan Wallen  Ain't That Some
# 96      Peso Pluma & Jasiel Nunez          Lagunas
# 97                     Noah Kahan       Dial Drunk
# 98  Jelly Roll With Lainey Wilson          Save Me
# 99                    Miley Cyrus            Jaded
#
# [100 rows x 2 columns]

# %%
concatenated_df = pd.concat([hot100, not_hot100]).drop_duplicates()
concatenated_df
# Out:
#                    Artist                          Title
# 0          Olivia Rodrigo                        Vampire
# 1           Morgan Wallen                     Last Night
# 2              Luke Combs                       Fast Car
# 3     Rema & Selena Gomez                      Calm Down
# 4             Miley Cyrus                        Flowers
# ...                   ...                            ...
# 5863     Kacey Musgraves                       good wife
# 8078      Anderson .Paak                          Trippy
# 4925       Playboi Carti                       Go2DaMoon
# 3722              Future                 LOVE YOU BETTER
# 7613              Future   The Percocet & Stripper Joint
#
# [2591 rows x 2 columns]

# %%
concatenated_df = concatenated_df.reset_index(drop=True)
concatenated_df
# Out:
#                    Artist                          Title
# 0          Olivia Rodrigo                        Vampire
# 1           Morgan Wallen                     Last Night
# 2              Luke Combs                       Fast Car
# 3     Rema & Selena Gomez                      Calm Down
# 4             Miley Cyrus                        Flowers
# ...                   ...                            ...
# 2586     Kacey Musgraves                       good wife
# 2587      Anderson .Paak                          Trippy
# 2588       Playboi Carti                       Go2DaMoon
# 2589              Future                 LOVE YOU BETTER
# 2590              Future   The Percocet & Stripper Joint
#
# [2591 rows x 2 columns]
